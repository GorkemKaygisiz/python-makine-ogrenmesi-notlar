# %%
import pandas as pd
import numpy as np

# %%
veri = pd.read_csv('data.csv')
veri
# Out:
#     calisma_suresi  uyku_suresi  kahve_miktari  sinav_notu
# 0                2            5              1          50
# 1                3            6              1          55
# 2                4            6              2          60
# 3                5            7              2          65
# 4                6            7              2          70
# 5                7            8              3          75
# 6                8            8              3          80
# 7                9            9              3          85
# 8               10            9              4          90
# 9                3            5              1          52
# 10               4            6              1          58
# 11               6            7              2          72
# 12               7            8              3          78
# 13               9            9              4          88

# %%
y= veri.iloc[:,-1:]
y
x= veri.iloc[:,0:3]
x
# Out:
#     calisma_suresi  uyku_suresi  kahve_miktari
# 0                2            5              1
# 1                3            6              1
# 2                4            6              2
# 3                5            7              2
# 4                6            7              2
# 5                7            8              3
# 6                8            8              3
# 7                9            9              3
# 8               10            9              4
# 9                3            5              1
# 10               4            6              1
# 11               6            7              2
# 12               7            8              3
# 13               9            9              4

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
#Makineyi eğitiyoruz eğitim verileriyle
x_train.shape
# Out:
# (9, 3)

# %%
y_pred =lr.predict(x_test)
y_pred
# Out:
# array([[90.49354839],
#        [79.56774194],
#        [68.64193548],
#        [68.64193548],
#        [60.42258065]])

# %%
import statsmodels.api as sm
#statsmodels kütüphanesi bizden tek başına 1'lerle dolu olan sütun eklememizi ister.

son_df = np.append(arr=np.ones((14,1)).astype(int),values =x,axis=1)

X_liste = np.array(son_df[:,[0,1,2,3,]],dtype=float)

model_stats = sm.OLS(y,X_liste).fit()
model_stats.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             sinav_notu   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     488.1
# Date:                Sun, 26 Apr 2026   Prob (F-statistic):           3.87e-11
# Time:                        15:17:42   Log-Likelihood:                -20.802
# No. Observations:                  14   AIC:                             49.60
# Df Residuals:                      10   BIC:                             52.16
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         30.4810      4.881      6.245      0.000      19.606      41.356
# ...

# %%
X_liste = np.array(son_df[:,[0,1,2]],dtype=float)
model_stats = sm.OLS(y,X_liste).fit()
model_stats.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             sinav_notu   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     657.0
# Date:                Sun, 26 Apr 2026   Prob (F-statistic):           3.59e-12
# Time:                        15:18:24   Log-Likelihood:                -22.217
# No. Observations:                  14   AIC:                             50.43
# Df Residuals:                      11   BIC:                             52.35
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         28.6405      4.982      5.748      0.000      17.674      39.607
# ...

# %%
X_liste = np.array(son_df[:,[0,1]],dtype=float)
model_stats = sm.OLS(y,X_liste).fit()
model_stats.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             sinav_notu   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                     1049.
# Date:                Sun, 26 Apr 2026   Prob (F-statistic):           4.75e-13
# Time:                        15:19:02   Log-Likelihood:                -24.382
# No. Observations:                  14   AIC:                             52.76
# Df Residuals:                      12   BIC:                             54.04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         38.4117      1.050     36.598      0.000      36.125      40.699
# ...

# %%
# GERÇEK NOTLAR VE MAKİNENİN SONUÇLARI
import matplotlib.pyplot as plt
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(14,5))

ax1.plot(range(len(y_test)),y_test,color='blue',label='Gerçek Notlar')
ax1.scatter(range(len(y_test)),y_pred,color='red', label='Tahmin notlar')
ax1.legend()


ax2.scatter(x_train[['calisma_suresi']],y_train,color='green')
m,b = np.polyfit(x_train['calisma_suresi'],y_train.values.flatten(),1)
ax2.plot(x_train[['calisma_suresi']],m*x_train[['calisma_suresi']]+b,color='orange')
plt.show()
