# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
veriler = pd.read_csv("veri.csv")
veriler.head()
#Hacim iş hacmi olarak düşünülebilir.
# Out:
#    No Cinsiyet  Yas  Hacim  Maas
# 0   1        K   60  69900  6325
# 1   2        K   30  79000  5200
# 2   3        E   52  85500  7825
# 3   4        E   57  17100  8375
# 4   5        E   55   5500  5450

# %%
X = veriler.iloc[:,3:].values
X
# Hacim ve maaş değerleini çekiyorum

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, init='k-means++')

kmeans.fit(X)
print(kmeans.cluster_centers_)
# Out:
# [[104386.95652174   7289.13043478]
#  [ 58643.47826087   5844.92753623]
#  [ 22069.41176471   5320.88235294]]

# %%
# K için optimum değeri bulmak
sonuclar =[]
for i in range (1,11):
    kmeans = KMeans(n_clusters =i, init ='k-means++', random_state=42)
    kmeans.fit(X)
    sonuclar.append(kmeans.inertia_) 
    # inertia_ WCSS değerlerini verir.

sonuclar
# Out:
# [242389902746.875,
#  69083288306.74913,
#  37446016326.835236,
#  19660743423.029793,
#  13627418346.478176,
#  8740876208.659988,
#  7120405752.7305,
#  5583056120.529261,
#  4565582690.869291,
#  3715492900.5772]

# %%
plt.plot(range(1,11),sonuclar)
